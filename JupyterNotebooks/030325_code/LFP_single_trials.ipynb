# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import time
import gc
import mne
from scipy.stats import zscore
from scipy.signal import detrend
import copy
np.set_printoptions(threshold=100)  # Default threshold
mne.set_log_level('WARNING')
import warnings
warnings.simplefilter("ignore", category=DeprecationWarning)

#this can run all of the pairs in ~ 
run_time = time.time()
file_numbers = [1, 2, 4, 8, 14, 15, 20, 23]


# classes_left = np.arange(0, 20)
# classes_right = np.arange(0, 20)

classes_left = np.arange(0,20)
classes_right = np.arange(0,20)


agg_structure = {f'dataset_{file_number}': 
                 {f'left_class_{class_left}': 
                  {f'right_class_{class_right}': [] for class_right in classes_right} for class_left in classes_left} for file_number in file_numbers}

left_input_LFP_attleft_agg = copy.deepcopy(agg_structure)
right_input_LFP_attleft_agg = copy.deepcopy(agg_structure)
attention_LFP_attleft_agg = copy.deepcopy(agg_structure)

left_input_LFP_attright_agg = copy.deepcopy(agg_structure)
right_input_LFP_attright_agg = copy.deepcopy(agg_structure)
attention_LFP_attright_agg = copy.deepcopy(agg_structure)

n_values = {f'dataset_{file_number}':
            {f'left_class_{class_left}':
             {f'right_class_{class_right}': {
                'attleft': [],
                'attright': []
                } for class_right in classes_right} for class_left in classes_left} for file_number in file_numbers}

total_time = time.time()
total_load_time = time.time()
for file_number in file_numbers:   #will first load the file and extract the data
    file_path = f'C:/Users/joshu/PartIIIProject/RSNNdale_attention_{file_number}_attention_test'
    load_data_start_time = time.time()
    data = pickle.load(open(file_path, 'rb'))
    elapsed_time = time.time() - load_data_start_time
    print(f"Dataset {file_number} loaded in {elapsed_time:.2f} seconds")
    file_process_time = time.time()

    attention_labels = data['label_attend'][0]
    label_left = data['label_left'][0]
    label_right = data['label_right'][0]
    attend_01 = data['attend'][0]
    omitted = data["omit"][0]

    # Extract LFP signals
    left_input_LFP = data['LFP'][0][0]
    right_input_LFP = data['LFP'][0][1]
    attention_LFP = data['LFP_rec'][0][2]

    for class_left in classes_left:
         for class_right in classes_right: 
    
            left_indices = np.where((omitted ==0) & (attend_01 == 0) & (label_left == class_left) & (label_right == class_right))[0]
            right_indices = np.where((omitted ==0) & (attend_01 == 1) & (label_left == class_left) & (label_right == class_right))[0]

            print(left_indices)
            print(right_indices)

            n_values[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'][f'attleft'] = [len(left_indices)]  #e.g. checks number of trials of this class combo for attentino left
            n_values[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'][f'attright'] = [len(right_indices)]  #nb need both left and right indices to be non empty

            if len(left_indices) >= 1:
                left_input_LFP_attleft = left_input_LFP[left_indices][:, 100:350]
                right_input_LFP_attleft = right_input_LFP[left_indices][:, 100:350]
                attention_LFP_attleft = attention_LFP[left_indices][:, 100:350]

                left_input_LFP_attleft_agg[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'].append(left_input_LFP_attleft)
                right_input_LFP_attleft_agg[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'].append(right_input_LFP_attleft)
                attention_LFP_attleft_agg[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'].append(attention_LFP_attleft)
                print(f'appended {len(left_indices)} trial(s) to left_agg datasets')

            if len(right_indices) >= 1:

                left_input_LFP_attright = left_input_LFP[right_indices][:, 100:350]
                right_input_LFP_attright = right_input_LFP[right_indices][:, 100:350]
                attention_LFP_attright = attention_LFP[right_indices][:, 100:350]

                left_input_LFP_attright_agg[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'].append(left_input_LFP_attright)   
                right_input_LFP_attright_agg[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'].append(right_input_LFP_attright)
                attention_LFP_attright_agg[f'dataset_{file_number}'][f'left_class_{class_left}'][f'right_class_{class_right}'].append(attention_LFP_attright)
                print(f'appended {len(right_indices)} trial(s) to right_agg datasets')

    del data
    gc.collect()
    elapsed_time = time.time() - file_process_time
    print(f"Dataset {file_number} processed in {elapsed_time:.2f} seconds")


# for file_number in file_numbers:
#     if left_input_LFP_attleft_agg[f'dataset_{file_number}']['left_class_12']['right_class_18']:
#         print(f"Dataset {file_number} has {len(left_input_LFP_attleft_agg[f'dataset_{file_number}']['left_class_12']['right_class_18'][0])} trials for left attleft")

# for file_number in file_numbers:
#     if left_input_LFP_attright_agg[f'dataset_{file_number}']['left_class_12']['right_class_18']:
#         print(f"Dataset {file_number} has {len(left_input_LFP_attright_agg[f'dataset_{file_number}']['left_class_12']['right_class_18'][0])} trials for left attright")

# for file_number in file_numbers:
#     print(f'n_values left for dataset {file_number} = {n_values[f"dataset_{file_number}"]["left_class_12"]["right_class_18"]["attleft"]}')

# for file_number in file_numbers:    
#     print(f'n_values right for dataset {file_number} = {n_values[f"dataset_{file_number}"]["left_class_12"]["right_class_18"]["attright"]}')


#dont want to process here - want to process when its in the big array
print(f'Total load time = {time.time() - total_load_time:.2f} seconds')

#-------formatting the trials into a single array for each class pair, of length n_samples * n_trials------------------
all_structure = {f'left_class_{class_left}': {f'right_class_{class_right}': [] for class_right in classes_right} for class_left in classes_left}

left_input_LFP_attleft_all = copy.deepcopy(all_structure)
right_input_LFP_attleft_all = copy.deepcopy(all_structure)
attention_LFP_attleft_all = copy.deepcopy(all_structure)

left_input_LFP_attright_all = copy.deepcopy(all_structure)
right_input_LFP_attright_all = copy.deepcopy(all_structure)
attention_LFP_attright_all = copy.deepcopy(all_structure)

for filenumber in file_numbers:
    for class_left in classes_left:
        for class_right in classes_right:
            left_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'].extend(left_input_LFP_attleft_agg[f'dataset_{filenumber}'][f'left_class_{class_left}'][f'right_class_{class_right}'])
            right_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'].extend(right_input_LFP_attleft_agg[f'dataset_{filenumber}'][f'left_class_{class_left}'][f'right_class_{class_right}'])
            attention_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'].extend(attention_LFP_attleft_agg[f'dataset_{filenumber}'][f'left_class_{class_left}'][f'right_class_{class_right}'])

            left_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'].extend(left_input_LFP_attright_agg[f'dataset_{filenumber}'][f'left_class_{class_left}'][f'right_class_{class_right}'])
            right_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'].extend(right_input_LFP_attright_agg[f'dataset_{filenumber}'][f'left_class_{class_left}'][f'right_class_{class_right}'])
            attention_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'].extend(attention_LFP_attright_agg[f'dataset_{filenumber}'][f'left_class_{class_left}'][f'right_class_{class_right}'])

#------ want to preprocess each array here now that they are properly compiled ----------------
# print('full left attleft', left_input_LFP_attleft_all["left_class_12"]["right_class_18"])
# print('full left attright',left_input_LFP_attright_all["left_class_12"]["right_class_18"])

for class_left in classes_left:
    for class_right in classes_right:
        left_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'] = np.vstack(left_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'] = np.vstack(right_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        attention_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'] = np.vstack(attention_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])

        left_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'] = np.vstack(left_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'] = np.vstack(right_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        attention_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'] = np.vstack(attention_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])

# print('full left attleft', left_input_LFP_attleft_all["left_class_12"]["right_class_18"], 'with length', len(left_input_LFP_attleft_all["left_class_12"]["right_class_18"]))
# print('full left attright',left_input_LFP_attright_all["left_class_12"]["right_class_18"], 'with length', len(left_input_LFP_attright_all["left_class_12"]["right_class_18"]))

left_attleft = copy.deepcopy(all_structure)
right_attleft = copy.deepcopy(all_structure)
att_attleft = copy.deepcopy(all_structure)

left_attright = copy.deepcopy(all_structure)
right_attright = copy.deepcopy(all_structure)
att_attright = copy.deepcopy(all_structure)


n_values_sum = {f'left_class_{class_left}': {f'right_class_{class_right}': {'attleft': 0, 'attright': 0} for class_right in classes_right} for class_left in classes_left}


for class_left in classes_left:
    for class_right in classes_right:
        n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attleft'] = sum(
            n_values[f'dataset_{dataset}'][f'left_class_{class_left}'][f'right_class_{class_right}']['attleft'][0] for dataset in file_numbers  #this will check through all the datasets 
        )
        n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attright'] = sum(
            n_values[f'dataset_{dataset}'][f'left_class_{class_left}'][f'right_class_{class_right}']['attright'][0] for dataset in file_numbers
        )

#this should now pick a class pair, and just sum the number in the dataset for each attention condition

# print('total number of trials in left attleft =', n_values_sum['left_class_12']['right_class_18']['attleft'])
# print('total number of trials in left attright =', n_values_sum['left_class_12']['right_class_18']['attright'])


for class_left in classes_left:
    for class_right in classes_right:
        left_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = (left_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = (right_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        att_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = (attention_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])

        left_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = (left_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = (right_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        att_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = (attention_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
# Out:
# Dataset 1 loaded in 16.53 seconds
# []
# [1596 1677]
# appended 2 trial(s) to right_agg datasets
# [1527]
# []
# appended 1 trial(s) to left_agg datasets
# [ 919 1731]
# [1621 1674]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [ 85 727]
# appended 2 trial(s) to right_agg datasets
# [1539 1643]
# [397]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1721]
# appended 1 trial(s) to right_agg datasets
# []
# []
# [628]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [210]
# appended 1 trial(s) to right_agg datasets
# [1153]
# []
# appended 1 trial(s) to left_agg datasets
# [ 903 1537]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [1305]
# appended 1 trial(s) to right_agg datasets
# []
# [1021 1604]
# appended 2 trial(s) to right_agg datasets
# [16]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [141]
# appended 1 trial(s) to right_agg datasets
# [1942 2003]
# [ 283  731  953 1579]
# appended 2 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# []
# [1360 1531]
# appended 2 trial(s) to right_agg datasets
# []
# [ 564 1050]
# appended 2 trial(s) to right_agg datasets
# [79]
# [652]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 99 599 812]
# appended 3 trial(s) to right_agg datasets
# [ 623 1150 1708]
# [1194]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 810 1034]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [ 660 1306]
# appended 2 trial(s) to right_agg datasets
# [1049 1171]
# [1972]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1275 1439]
# [ 897 1836 1852]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [860]
# appended 1 trial(s) to right_agg datasets
# [836]
# [ 37 614]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [966]
# [270]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [718]
# []
# appended 1 trial(s) to left_agg datasets
# [ 235  494 1454]
# [ 532 1018 1486]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [113 589]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [742 894]
# appended 2 trial(s) to right_agg datasets
# [104]
# []
# appended 1 trial(s) to left_agg datasets
# [  60 1446 1447]
# []
# appended 3 trial(s) to left_agg datasets
# []
# [1690 1829]
# appended 2 trial(s) to right_agg datasets
# [1308]
# [ 691 1756]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [89]
# [2009]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 400  531  663 1290]
# [1973]
# appended 4 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1286 1646]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [150]
# appended 1 trial(s) to right_agg datasets
# [ 184 1100]
# [833]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [487 955]
# [48]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [569]
# [700]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1094 1132 1903 1951]
# []
# appended 4 trial(s) to left_agg datasets
# [196]
# [1252]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 142  635  662  885 1547]
# [ 370 1134]
# appended 5 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [657 698 893]
# appended 3 trial(s) to right_agg datasets
# [910]
# [1686]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 106  186 1497 1982]
# [1515]
# appended 4 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1278 1420]
# [128]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 315 1593]
# appended 2 trial(s) to right_agg datasets
# [  4 624]
# [777]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 744 1445]
# [1892]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1253]
# []
# appended 1 trial(s) to left_agg datasets
# [1060]
# [585]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1145]
# [495]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [498 638]
# [650 856]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [775]
# [375]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1332 2014]
# appended 2 trial(s) to right_agg datasets
# []
# []
# [133]
# [ 956 1542 1747]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 739 1569]
# [601 866 907]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [784]
# appended 1 trial(s) to right_agg datasets
# []
# [  54 2019]
# appended 2 trial(s) to right_agg datasets
# [1116 1161]
# [687]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1216]
# appended 1 trial(s) to right_agg datasets
# [1837]
# [634]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [607]
# [ 503  709 1051 1659]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [1370]
# []
# appended 1 trial(s) to left_agg datasets
# [1213 1362]
# [752]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 380  478 1047]
# [1062 1633]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [541]
# [1833]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1466]
# []
# appended 1 trial(s) to left_agg datasets
# [328 466]
# [1433 1928]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1242 1991]
# [497]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [453]
# [41]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [  97 1922]
# [711 967 989]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [931]
# [ 935 1736]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1474]
# [ 152 2018]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [1296]
# appended 1 trial(s) to right_agg datasets
# []
# [1761]
# appended 1 trial(s) to right_agg datasets
# [24]
# [ 499 1084 1091 1941]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [1358]
# [1493 1589]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1019 1507]
# [630]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [ 182 1149 1554]
# appended 3 trial(s) to right_agg datasets
# [1492 2031]
# [1212 1471 1882]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# []
# [1089]
# [ 257  843 1386 1963]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [1109]
# [484]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [447 461 702]
# []
# appended 3 trial(s) to left_agg datasets
# []
# []
# [ 525 1320 1702]
# [1107 1472]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [120]
# [1186 1413]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [1806]
# appended 1 trial(s) to right_agg datasets
# []
# [1449]
# appended 1 trial(s) to right_agg datasets
# []
# [ 835 1210 1226]
# appended 3 trial(s) to right_agg datasets
# [382]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1260 1978]
# appended 2 trial(s) to right_agg datasets
# [ 563 1099]
# [1217]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# []
# [ 942 1480]
# [ 434  582 1828]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1920]
# [1701 2000]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [ 875  988 1712]
# appended 3 trial(s) to right_agg datasets
# [1815]
# [ 384 1090]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 124  644 1001 1359]
# []
# appended 4 trial(s) to left_agg datasets
# [1156]
# [226]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 505  542 1879]
# [ 218  982 1838]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1727]
# [636]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [304]
# [933]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [  68  820  895 1124]
# appended 4 trial(s) to right_agg datasets
# []
# [948]
# appended 1 trial(s) to right_agg datasets
# [1032]
# []
# appended 1 trial(s) to left_agg datasets
# [ 138 1688]
# [ 782 1234]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [  70  917 1578]
# [ 320 1249]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [  57 1012 1819]
# [1799]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1514]
# appended 1 trial(s) to right_agg datasets
# []
# [1625]
# appended 1 trial(s) to right_agg datasets
# [ 409 1735]
# [351]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1072]
# [ 610 1310 1404]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [677]
# [973]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1468]
# [ 319 1240]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1605]
# [  47  313 1818]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 258 1164]
# [1157]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1040 1387 1529]
# [1224]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [549]
# [ 297 1435]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1382]
# []
# appended 1 trial(s) to left_agg datasets
# [ 756 1027 1331]
# []
# appended 3 trial(s) to left_agg datasets
# [256]
# [ 699 1714]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [6]
# appended 1 trial(s) to right_agg datasets
# [331]
# [ 701 1208]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [323]
# [140]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [407 855]
# [975]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1835]
# [ 846 1826]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [1699]
# appended 1 trial(s) to right_agg datasets
# [ 67 115]
# []
# appended 2 trial(s) to left_agg datasets
# [277]
# [ 263 1067 1543]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [ 365 1660]
# appended 2 trial(s) to right_agg datasets
# [ 291 1104]
# [78]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1282]
# [ 513 1061]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1987]
# [ 162  276  332 1511]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [139]
# [424]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1147 1277 1524 1902]
# [ 674 1185]
# appended 4 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1003]
# [ 707 1101]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1131]
# [689]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1311]
# appended 1 trial(s) to right_agg datasets
# [280]
# []
# appended 1 trial(s) to left_agg datasets
# [295 759]
# [861]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [191]
# appended 1 trial(s) to right_agg datasets
# []
# [  58  598 1683 1915]
# appended 4 trial(s) to right_agg datasets
# [439]
# [293]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 398 1573]
# []
# appended 2 trial(s) to left_agg datasets
# [ 930 1636]
# [ 121  789  896 1629]
# appended 2 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [61]
# [516]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1235]
# []
# appended 1 trial(s) to left_agg datasets
# [1820]
# [1921]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1885]
# [165]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 412  555  909 1789]
# []
# appended 4 trial(s) to left_agg datasets
# [ 877 1065 1730]
# [1165]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1220]
# []
# appended 1 trial(s) to left_agg datasets
# [1496]
# [1557]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1853]
# []
# appended 1 trial(s) to left_agg datasets
# [ 671 1888]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [469 961]
# appended 2 trial(s) to right_agg datasets
# [ 477 1795 1983]
# [62]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 451 1538]
# [1634]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [974]
# [ 340  668 1767 1812 1953]
# appended 1 trial(s) to left_agg datasets
# appended 5 trial(s) to right_agg datasets
# [ 679 1315]
# [1302]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 572  743 1648]
# [ 274  281 1079]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [248]
# [1504 1601]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [538]
# [1886]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [314]
# appended 1 trial(s) to right_agg datasets
# [1506 1550 1797]
# []
# appended 3 trial(s) to left_agg datasets
# [223]
# [ 212  444 2011 2012]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [153]
# []
# appended 1 trial(s) to left_agg datasets
# [ 159 1783]
# [190 344]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# []
# [ 364  511  923 1023]
# [1814]
# appended 4 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1411]
# [2005]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [749 853]
# [ 438 1824 1880]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [594 733]
# [553]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1782]
# [ 615  792 1078]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1423]
# [ 496  878 1383 1906]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# []
# [863]
# appended 1 trial(s) to right_agg datasets
# [1623]
# [1532]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 234 1361 1715]
# []
# appended 3 trial(s) to left_agg datasets
# [  92  463  927 1875]
# []
# appended 4 trial(s) to left_agg datasets
# [848]
# [1710]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [  65  977 1028 1948]
# [1587]
# appended 4 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [641]
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1691]
# []
# appended 1 trial(s) to left_agg datasets
# []
# []
# []
# [1127 1272 1575 2001]
# appended 4 trial(s) to right_agg datasets
# []
# []
# [1615]
# []
# appended 1 trial(s) to left_agg datasets
# [954]
# [ 519 1807]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 857 1865]
# [ 321 1808]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [88]
# [ 199  841 1225]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [337 790]
# [ 690  829 1544]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1916]
# [1323 1549]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1546]
# []
# appended 1 trial(s) to left_agg datasets
# [1176 1901]
# [1685]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1477 1582 1725 1851]
# [ 83 312]
# appended 4 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [432 465 665]
# []
# appended 3 trial(s) to left_agg datasets
# [1367]
# [21]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [666]
# [1682]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1707]
# [187 326]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1349 1719]
# [ 425 1066 1500 1960]
# appended 2 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [751]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1641]
# appended 1 trial(s) to right_agg datasets
# [1977]
# [1722]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 201  925 1016 1986]
# appended 4 trial(s) to right_agg datasets
# [ 486 1501]
# [279]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1463 1768]
# [ 559  710 1774]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [ 250 1561]
# appended 2 trial(s) to right_agg datasets
# [ 659 1231]
# [437 571]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 987 1438]
# [ 352  874 1356]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [753]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1844]
# appended 1 trial(s) to right_agg datasets
# []
# [ 306 1899]
# appended 2 trial(s) to right_agg datasets
# [1011]
# []
# appended 1 trial(s) to left_agg datasets
# [303 705 968]
# [ 884 2008]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1898]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [ 302  946 1126]
# appended 3 trial(s) to right_agg datasets
# [224 750]
# [1697]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [35]
# [1693]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 688 1810]
# [  19  355 1494]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 183  837 1995]
# []
# appended 3 trial(s) to left_agg datasets
# [   0 1672]
# [ 734 1481 1827]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 558 1339 1526]
# [1564 1925]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1187]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1271 1475]
# appended 2 trial(s) to right_agg datasets
# []
# [1868 1965]
# appended 2 trial(s) to right_agg datasets
# [395]
# [ 740 1096]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [530]
# []
# appended 1 trial(s) to left_agg datasets
# [715 762]
# []
# appended 2 trial(s) to left_agg datasets
# [1384]
# [934]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 485 1239]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [ 686 1144 1583 1665]
# appended 4 trial(s) to right_agg datasets
# [356 964]
# [1158 1279]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1558]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [ 536  545 1081]
# appended 3 trial(s) to right_agg datasets
# []
# [ 56 600]
# appended 2 trial(s) to right_agg datasets
# []
# [ 868 1375]
# appended 2 trial(s) to right_agg datasets
# [692]
# [  76  575  716  983 1656 1784]
# appended 1 trial(s) to left_agg datasets
# appended 6 trial(s) to right_agg datasets
# [ 972 1022]
# [371 938]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1006]
# [1876]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1790]
# [ 179  394 1251 1681 1754]
# appended 1 trial(s) to left_agg datasets
# appended 5 trial(s) to right_agg datasets
# [342]
# []
# appended 1 trial(s) to left_agg datasets
# [1030 1301]
# [1448 1585]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# []
# [117 918]
# []
# appended 2 trial(s) to left_agg datasets
# [ 738 1519]
# [1262]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [231]
# []
# appended 1 trial(s) to left_agg datasets
# []
# []
# [ 401 1207 1669]
# [1476]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [526]
# [ 305 1568]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1136 1295 1739]
# [360]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1602]
# [ 215 1867]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1388]
# []
# appended 1 trial(s) to left_agg datasets
# []
# []
# [308 957]
# [271]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1114]
# appended 1 trial(s) to right_agg datasets
# []
# [ 383 2002]
# appended 2 trial(s) to right_agg datasets
# [1910]
# [ 403 1025 1864]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 588 1424]
# [249 265 554]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1180]
# [1562]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [672 870]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [ 584 1347]
# appended 2 trial(s) to right_agg datasets
# []
# [ 627 1291]
# appended 2 trial(s) to right_agg datasets
# [ 100  609 1055]
# [1121]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [272]
# appended 1 trial(s) to right_agg datasets
# [ 381 1513]
# [ 807 1860 1984]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1975]
# []
# appended 1 trial(s) to left_agg datasets
# [310]
# [207]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [443 746 851]
# appended 3 trial(s) to right_agg datasets
# [  23 1123]
# [488]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1704]
# []
# appended 1 trial(s) to left_agg datasets
# [25]
# [748]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1620]
# [261]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 724  891 1650]
# []
# appended 3 trial(s) to left_agg datasets
# [ 289  445  990 1390]
# []
# appended 4 trial(s) to left_agg datasets
# [1205]
# [818]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 631 1054]
# [1068 1467 1770]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [ 399 1862]
# appended 2 trial(s) to right_agg datasets
# [1]
# [ 617 1340]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [481]
# [ 237 1781]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [318]
# [ 197 1237 1259]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1750]
# [645]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 681  939 1600]
# appended 3 trial(s) to right_agg datasets
# [1680]
# [  64  664  926 1490]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [ 468 1005 1597]
# [ 317 1832]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [ 357  803 1402]
# appended 3 trial(s) to right_agg datasets
# [ 533 1063 1622 1805]
# [1314]
# appended 4 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [1869]
# appended 1 trial(s) to right_agg datasets
# [1039]
# [ 110  658 1611]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [  82 1247 1553]
# appended 3 trial(s) to right_agg datasets
# []
# [125]
# appended 1 trial(s) to right_agg datasets
# []
# [1408]
# appended 1 trial(s) to right_agg datasets
# [1525 1804 1943]
# [ 109  243 1759]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [ 225 1863 1877]
# appended 3 trial(s) to right_agg datasets
# [788]
# [ 131  729 1534 1894]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# []
# [1976]
# appended 1 trial(s) to right_agg datasets
# [ 148 1097 1188]
# []
# appended 3 trial(s) to left_agg datasets
# []
# [ 285 1485 1772 1841]
# appended 4 trial(s) to right_agg datasets
# [  91 2023]
# [166]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 720  773  795 1357 1616 1854]
# [ 682 1227]
# appended 6 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [260 415 991]
# [ 902 1971]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 633 2029]
# []
# appended 2 trial(s) to left_agg datasets
# [1470]
# []
# appended 1 trial(s) to left_agg datasets
# [241 958]
# [ 330 1297]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1825]
# [ 562 1192]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1432]
# [1137]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1994]
# [723 996]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [728]
# []
# appended 1 trial(s) to left_agg datasets
# [832]
# [1726]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 28 307]
# [ 827 1280]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [118 669 847]
# [ 583  649 1193]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1318 1952]
# []
# appended 2 trial(s) to left_agg datasets
# [1874]
# [1233 1956]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 334 1465]
# [1695]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 185 1377]
# appended 2 trial(s) to right_agg datasets
# [1002]
# [ 458 1143 1974]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 570 1263 1289 1533]
# [278]
# appended 4 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [  27  146 1045 1329]
# [286 287]
# appended 4 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [388]
# [963]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 95 813]
# [655]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1246]
# [236 417]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [721]
# [993]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1776 1905]
# appended 2 trial(s) to right_agg datasets
# [ 797  798 2015]
# [ 882 1666]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 316  613 1080]
# [ 31 741]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 216 2024]
# []
# appended 2 trial(s) to left_agg datasets
# [1897]
# [567]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [696]
# [ 14 518]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1771]
# [1505]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [247 647]
# [ 995 1044 1607]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [59]
# []
# appended 1 trial(s) to left_agg datasets
# [208]
# [1437]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [  38  454 1140]
# [898]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1728]
# appended 1 trial(s) to right_agg datasets
# [  29 1341 1612 2021]
# []
# appended 4 trial(s) to left_agg datasets
# [107]
# [1056 1057]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# []
# [ 149  906 1170 1752]
# [ 252 1617]
# appended 4 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1070]
# [175]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [436]
# [11]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [423]
# [1120 1299 1794]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [213]
# []
# appended 1 trial(s) to left_agg datasets
# [406 763]
# [172 220]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1676]
# [581]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [1209 1791]
# appended 2 trial(s) to right_agg datasets
# [1631]
# [292]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [626]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [ 102  390 1816]
# appended 3 trial(s) to right_agg datasets
# [1325 1393]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [90]
# appended 1 trial(s) to right_agg datasets
# [ 129  537 1410 1452]
# []
# appended 4 trial(s) to left_agg datasets
# []
# [ 108 1385]
# appended 2 trial(s) to right_agg datasets
# [779]
# [ 325  781 1667]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1552 1913]
# [ 467 1284]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [561]
# [1345]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1214]
# [ 251 1606]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1559]
# []
# appended 1 trial(s) to left_agg datasets
# [ 242 1401]
# [1651]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [167]
# [ 754 1211 1632 1964]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [1206 1661 1884]
# [1679]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1425 1817]
# []
# appended 2 trial(s) to left_agg datasets
# [817]
# [111]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [ 204  883  986 1148 1969]
# appended 5 trial(s) to right_agg datasets
# [52]
# [1035 1250]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [32]
# [1398]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 268 1891]
# []
# appended 2 trial(s) to left_agg datasets
# [616 850]
# [1004]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 799 1015 1744]
# [1075 1098]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1378]
# [1380]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [282]
# [  51 1626 1687]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1696]
# [ 472 1642]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [420]
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [ 339  780 1462]
# appended 3 trial(s) to right_agg datasets
# []
# [969]
# appended 1 trial(s) to right_agg datasets
# []
# [1802]
# appended 1 trial(s) to right_agg datasets
# [577]
# [1113]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1831]
# appended 1 trial(s) to right_agg datasets
# [758]
# [ 181  244  358 1429]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# []
# []
# []
# [ 324 1989]
# appended 2 trial(s) to right_agg datasets
# Dataset 1 processed in 1.87 seconds
# Dataset 2 loaded in 6.26 seconds
# []
# []
# [1198]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [711]
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1007 1418 1611 1770]
# [1147 1160 1763]
# appended 4 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 293 1604]
# [ 775 1071 1133]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1227]
# [ 134 1196]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# []
# []
# []
# []
# []
# []
# [23]
# appended 1 trial(s) to right_agg datasets
# [  18 1296]
# [736]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [346]
# appended 1 trial(s) to right_agg datasets
# [690]
# [ 942 1088]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 800 1610]
# [ 789  953 1443]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1165 1484]
# [159 924]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# []
# []
# [342 431 887]
# appended 3 trial(s) to right_agg datasets
# [ 612  728 1244]
# [ 274 1104]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [841]
# []
# appended 1 trial(s) to left_agg datasets
# [616]
# [1510 1956]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [525]
# []
# appended 1 trial(s) to left_agg datasets
# [ 147 1315]
# [ 483  664 1572]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [ 511 1319]
# appended 2 trial(s) to right_agg datasets
# [ 694 1054 1556]
# []
# appended 3 trial(s) to left_agg datasets
# [ 635  970 1136]
# []
# appended 3 trial(s) to left_agg datasets
# []
# [66]
# appended 1 trial(s) to right_agg datasets
# [684 765]
# [1332 1746]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1240 1936]
# []
# appended 2 trial(s) to left_agg datasets
# [1062]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [108 455 846]
# appended 3 trial(s) to right_agg datasets
# [186]
# [ 211 1096 1422 1985]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [  31 1126]
# []
# appended 2 trial(s) to left_agg datasets
# [1545]
# [ 844 1526 1717]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [ 989 1979]
# appended 2 trial(s) to right_agg datasets
# [1417 1627 1639]
# [1247]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [1573]
# appended 1 trial(s) to right_agg datasets
# []
# []
# [889]
# [1750]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 101 1553]
# [1270]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 213 1509]
# [ 112 1380]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [123]
# appended 1 trial(s) to right_agg datasets
# []
# [ 183 1518]
# appended 2 trial(s) to right_agg datasets
# [  84 1729]
# [1435]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 532 1052]
# [1780]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [350]
# [588 782 927]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [655 701]
# []
# appended 2 trial(s) to left_agg datasets
# [994]
# []
# appended 1 trial(s) to left_agg datasets
# [322 606]
# [1962]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 628 1515]
# [331 478]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [502]
# appended 1 trial(s) to right_agg datasets
# [908]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1889]
# appended 1 trial(s) to right_agg datasets
# [1613]
# [659]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [876]
# appended 1 trial(s) to right_agg datasets
# [ 130  716 1308 2006]
# []
# appended 4 trial(s) to left_agg datasets
# []
# []
# [1708]
# [587]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1039 1271 1352]
# [1183]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1048]
# appended 1 trial(s) to right_agg datasets
# [752]
# []
# appended 1 trial(s) to left_agg datasets
# [1857]
# [1224]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [880]
# appended 1 trial(s) to right_agg datasets
# []
# [1206 1406]
# appended 2 trial(s) to right_agg datasets
# []
# [1525]
# appended 1 trial(s) to right_agg datasets
# [117]
# [878]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 990 1939]
# [1540]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1520]
# appended 1 trial(s) to right_agg datasets
# [1906]
# [1835]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1822]
# [1439 1599]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [ 719 1461 1579 1761]
# appended 4 trial(s) to right_agg datasets
# []
# []
# []
# [1260]
# appended 1 trial(s) to right_agg datasets
# []
# [57]
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [754]
# appended 1 trial(s) to right_agg datasets
# [25]
# [ 812  814 1605]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 248  783 1841]
# []
# appended 3 trial(s) to left_agg datasets
# [827]
# [1237]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1465 1698]
# [ 788 1310 1802]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [857]
# []
# appended 1 trial(s) to left_agg datasets
# [40]
# [175 961]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1297 1754]
# [1916]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1963]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1829]
# appended 1 trial(s) to right_agg datasets
# [52]
# [ 145  897 1019]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1908]
# [1078 1185 1524 1571]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [740]
# [ 307 1012]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [28]
# []
# appended 1 trial(s) to left_agg datasets
# [1202 1328]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [106]
# appended 1 trial(s) to right_agg datasets
# [366]
# [ 351 1768 1905]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1709 1992]
# []
# appended 2 trial(s) to left_agg datasets
# [901]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [  15  952 1819]
# appended 3 trial(s) to right_agg datasets
# [1338]
# [ 987 1031 1410]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [65]
# [1044 1156]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [583]
# []
# appended 1 trial(s) to left_agg datasets
# [ 347 1882]
# []
# appended 2 trial(s) to left_agg datasets
# [1372 1382 1559 1742]
# [ 674 1329 1823]
# appended 4 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [ 138 1998]
# appended 2 trial(s) to right_agg datasets
# [1211 1475 1776]
# [165 482]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [100 102 955]
# []
# appended 3 trial(s) to left_agg datasets
# [1976]
# []
# appended 1 trial(s) to left_agg datasets
# [  43 2011]
# [ 32 668]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1192 1940]
# [1608]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1432]
# []
# appended 1 trial(s) to left_agg datasets
# [402 464]
# []
# appended 2 trial(s) to left_agg datasets
# [ 206 1356]
# [437 836]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 512 1291]
# [105]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 26 848]
# [1360 1756]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1612]
# [264 504]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1166 1972]
# [340]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 985 1243 1436]
# [284]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [323]
# [1988]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [1702]
# [ 869 1404 1833]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [863 948]
# []
# appended 2 trial(s) to left_agg datasets
# [289 922]
# []
# appended 2 trial(s) to left_agg datasets
# [300]
# []
# appended 1 trial(s) to left_agg datasets
# [642 679]
# [795]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 865 1368 1669]
# appended 3 trial(s) to right_agg datasets
# [ 245  569 1749]
# [ 543 1881]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [392]
# []
# appended 1 trial(s) to left_agg datasets
# [1386]
# []
# appended 1 trial(s) to left_agg datasets
# [1199 1580]
# [  59  157 1828]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1040 1468]
# [ 438 1204]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# []
# [ 358 1285]
# [251 747]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1593]
# [1487 1531]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1434]
# [ 327  914 1932]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1462]
# [1562]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1150 1529 1907]
# []
# appended 3 trial(s) to left_agg datasets
# [640]
# [226]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [965]
# [453]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 78 312 408]
# []
# appended 3 trial(s) to left_agg datasets
# [1575]
# [1695]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [96]
# []
# appended 1 trial(s) to left_agg datasets
# [ 115 1188 1335]
# [704]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1899]
# appended 1 trial(s) to right_agg datasets
# []
# [55]
# appended 1 trial(s) to right_agg datasets
# []
# [39]
# appended 1 trial(s) to right_agg datasets
# [216]
# [1035]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1715]
# appended 1 trial(s) to right_agg datasets
# []
# [ 519 1796 2016]
# appended 3 trial(s) to right_agg datasets
# [121]
# [ 691  749 1597]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [1885]
# appended 1 trial(s) to right_agg datasets
# []
# [856 944]
# appended 2 trial(s) to right_agg datasets
# [1942]
# [ 460 1688]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [1119]
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [1640 1810]
# appended 2 trial(s) to right_agg datasets
# [756]
# []
# appended 1 trial(s) to left_agg datasets
# [447]
# [1968]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 308 1347]
# [445 790]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1214]
# [ 597  811 1501]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [1287 1293]
# appended 2 trial(s) to right_agg datasets
# [2009]
# [1569]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 164 1002]
# [998]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 266  403 1163]
# [1678]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 377  441 1324]
# [ 417 1235]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [995]
# [645]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [510]
# [180]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [375]
# [ 209 1816]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1194 1429]
# [ 276 1395]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [858 972]
# [1507 1960]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1647]
# [943]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1896]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1168 1379]
# appended 2 trial(s) to right_agg datasets
# [395 527 666]
# []
# appended 3 trial(s) to left_agg datasets
# [738]
# [156]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [963]
# []
# appended 1 trial(s) to left_agg datasets
# [625 770 785]
# [259 835]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 388  585 1642]
# [185 786]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [  4 406]
# appended 2 trial(s) to right_agg datasets
# []
# [1677 1681 1837]
# appended 3 trial(s) to right_agg datasets
# [1219]
# [1844]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 624 1409]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [ 292 1901]
# appended 2 trial(s) to right_agg datasets
# []
# [1317]
# appended 1 trial(s) to right_agg datasets
# [ 354 1098]
# []
# appended 2 trial(s) to left_agg datasets
# [1506]
# [909]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 815 1997]
# [652]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1934]
# appended 1 trial(s) to right_agg datasets
# [1018]
# []
# appended 1 trial(s) to left_agg datasets
# [  68  877 1990]
# [75]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 578 1452]
# [1634]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1292]
# []
# appended 1 trial(s) to left_agg datasets
# [459]
# [ 301 1798]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [1266 1583 1831]
# appended 3 trial(s) to right_agg datasets
# []
# [ 190 1298]
# appended 2 trial(s) to right_agg datasets
# []
# []
# [1181]
# []
# appended 1 trial(s) to left_agg datasets
# [ 368  608  703 1596 1855]
# []
# appended 5 trial(s) to left_agg datasets
# [1011]
# [1918]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [882]
# [86]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 316 1902]
# appended 2 trial(s) to right_agg datasets
# []
# []
# []
# [1726]
# appended 1 trial(s) to right_agg datasets
# [  70  143  546 1982]
# []
# appended 4 trial(s) to left_agg datasets
# [1451]
# [ 93 270 884]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [169]
# []
# appended 1 trial(s) to left_agg datasets
# [ 329 2019]
# [631]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [352]
# []
# appended 1 trial(s) to left_agg datasets
# [696]
# [1759]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1207 1231 1840]
# [ 126  298 1290 1607]
# appended 3 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [ 538  769 1152]
# [237 687 933]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [  63 1755]
# appended 2 trial(s) to right_agg datasets
# [ 282  650 1117]
# [1704]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 224 1153]
# appended 2 trial(s) to right_agg datasets
# []
# [ 396 1267 1858]
# appended 3 trial(s) to right_agg datasets
# [ 451 1655]
# [1159 1371]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1373 1869]
# []
# appended 2 trial(s) to left_agg datasets
# [ 554 1469]
# [651 667]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 232  910 1286 1773 1964]
# [223 539 630]
# appended 5 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [416 424]
# [ 872 1331 1784]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [1471 1585]
# appended 2 trial(s) to right_agg datasets
# [1072]
# []
# appended 1 trial(s) to left_agg datasets
# [1309]
# [89]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 162 1321 1453 1644]
# appended 4 trial(s) to right_agg datasets
# [ 253 1108]
# [1275 1792 1814]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [371 773]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [531 713]
# appended 2 trial(s) to right_agg datasets
# []
# []
# []
# []
# []
# [1581 1657]
# ...
# appended 1 trial(s) to right_agg datasets
# [735 745]
# [617]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [923]
# [1290 1340]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [259]
# [1668]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [105]
# [ 174  292  899 1387]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [1259]
# [ 751 1803]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [4]
# []
# appended 1 trial(s) to left_agg datasets
# [1368]
# [1037]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1025 1415]
# appended 2 trial(s) to right_agg datasets
# [464 895]
# [195 274]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 209  950 1180]
# [1892]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [89]
# [203 445]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1376]
# [ 498 1513]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [411 927]
# appended 2 trial(s) to right_agg datasets
# [ 148 1573 1606]
# [  22  939 1026 1275]
# appended 3 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# []
# [505]
# appended 1 trial(s) to right_agg datasets
# [  60 1421 1977]
# [ 386  673 1491]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [288]
# [184 659]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1054 1520]
# [67]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 664  760 1599]
# [969]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [  74 1868]
# [1362]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1682 1910]
# appended 2 trial(s) to right_agg datasets
# [  96 1375 1728]
# [ 814 1660]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 682 1845]
# [887]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 915 1945]
# [1541 2026]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [828]
# [1000]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 962 1580]
# appended 2 trial(s) to right_agg datasets
# []
# []
# [1987]
# []
# appended 1 trial(s) to left_agg datasets
# [ 275 1780]
# [1057]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 369  607 1232]
# [1123 1212]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1652]
# []
# appended 1 trial(s) to left_agg datasets
# []
# []
# [562 835]
# [ 581 1031 1539]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 844 1998]
# []
# appended 2 trial(s) to left_agg datasets
# [ 370  982 1204 1771]
# [ 878  989 1299 1929]
# appended 4 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [1161 1603]
# [0]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1252]
# [ 311 1086 1646]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1960]
# [641 861]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 157 1710 1991]
# [499 501]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [118 330 979]
# appended 3 trial(s) to right_agg datasets
# [1469 1616 1811]
# [1601]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [117]
# appended 1 trial(s) to right_agg datasets
# [ 150 1904]
# [1439]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [1568 1785]
# appended 2 trial(s) to right_agg datasets
# [ 688 1711]
# [111 517 594 991]
# appended 2 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# []
# [  77 1280 1613]
# appended 3 trial(s) to right_agg datasets
# [1898]
# [   5  380  685  701 1432]
# appended 1 trial(s) to left_agg datasets
# appended 5 trial(s) to right_agg datasets
# [1826]
# [1859 1924]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [214 768 843 940]
# appended 4 trial(s) to right_agg datasets
# [1440]
# [ 649 1882]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# [258 352]
# appended 2 trial(s) to right_agg datasets
# [ 722  998 1191]
# [ 552  576  699 1399]
# appended 3 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [331]
# []
# appended 1 trial(s) to left_agg datasets
# [518]
# [ 250 1152]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [608]
# [777]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 271 1544]
# []
# appended 2 trial(s) to left_agg datasets
# [1188]
# []
# appended 1 trial(s) to left_agg datasets
# [ 476 1656]
# []
# appended 2 trial(s) to left_agg datasets
# [1231]
# [ 429 1457]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 164  551 1326]
# [838 849]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [204 779]
# [ 266  418 1878]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 615  635 1125]
# [679]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1115]
# appended 1 trial(s) to right_agg datasets
# [ 748 1009]
# []
# appended 2 trial(s) to left_agg datasets
# [365]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [705]
# appended 1 trial(s) to right_agg datasets
# []
# [715 917]
# appended 2 trial(s) to right_agg datasets
# []
# [818]
# appended 1 trial(s) to right_agg datasets
# [1565]
# [276]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1312 1947]
# [ 854 1709]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 394 1388]
# [309]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [162 399 595 966 988]
# [1377 1598]
# appended 5 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 774 1111]
# [953]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [137 610 865]
# appended 3 trial(s) to right_agg datasets
# [282]
# [  14  776 1609]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [35]
# [ 140 1279]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1006 1017 1202]
# [ 837 1194 2013]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [1427 1961]
# appended 2 trial(s) to right_agg datasets
# [1671]
# [328 433]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [485 696]
# [ 180  744 1233 1608]
# appended 2 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# []
# [1667]
# appended 1 trial(s) to right_agg datasets
# [1983]
# [1720]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [419]
# []
# appended 1 trial(s) to left_agg datasets
# [ 757  996 1363]
# []
# appended 3 trial(s) to left_agg datasets
# [ 471 1796]
# []
# appended 2 trial(s) to left_agg datasets
# [ 902 1393 1727]
# [106 444 840]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1507]
# [1566]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [790]
# appended 1 trial(s) to right_agg datasets
# [245]
# [1327]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1822]
# [ 329 1498 1567]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 107 1158 1926]
# [893]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [467]
# [ 474  762 1309]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1163 1289]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [1744]
# appended 1 trial(s) to right_agg datasets
# [ 319 1334]
# [1921]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [841]
# [314 402]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [532]
# [1341]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [  61  972 1386]
# []
# appended 3 trial(s) to left_agg datasets
# [1051 1982]
# [1333 1478]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 169  230 1774]
# []
# appended 3 trial(s) to left_agg datasets
# [  91 1208]
# [1142]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [26]
# []
# appended 1 trial(s) to left_agg datasets
# [199]
# []
# appended 1 trial(s) to left_agg datasets
# []
# []
# []
# [1807]
# appended 1 trial(s) to right_agg datasets
# []
# [2002]
# appended 1 trial(s) to right_agg datasets
# []
# []
# []
# [1479 1705 1848]
# appended 3 trial(s) to right_agg datasets
# [ 220 1739]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [1726 1907]
# appended 2 trial(s) to right_agg datasets
# [ 293 1527 1755 1917]
# [876]
# appended 4 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 219 1253]
# appended 2 trial(s) to right_agg datasets
# [1053]
# [ 702 1918]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 56 900]
# []
# appended 2 trial(s) to left_agg datasets
# [463 896]
# []
# appended 2 trial(s) to left_agg datasets
# []
# []
# [ 674 1587 1741]
# [821 945]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 384  435 1772]
# [334 795]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# []
# []
# []
# []
# [1782]
# [1761 1869]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1553]
# [210]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 200  448  508 1528]
# appended 4 trial(s) to right_agg datasets
# []
# [554]
# appended 1 trial(s) to right_agg datasets
# [1653 1781]
# [ 765 1174 1692 1760]
# appended 2 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [970]
# [1041]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 929 1474]
# appended 2 trial(s) to right_agg datasets
# [ 302 1855]
# [1211 1514]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1751]
# [ 249  820  868 1472]
# appended 1 trial(s) to left_agg datasets
# appended 4 trial(s) to right_agg datasets
# [656 662 788]
# [515]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [586]
# appended 1 trial(s) to right_agg datasets
# [113 225]
# [1441 1467]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1802 1912]
# [700]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [461 830]
# [344]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [987]
# []
# appended 1 trial(s) to left_agg datasets
# [ 290  645 1734]
# [ 578 1793]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [  30 1659]
# [ 761 1696]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [208 773]
# [ 128  750 1045]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [1159 1581 1867]
# appended 3 trial(s) to right_agg datasets
# [ 706 1120]
# []
# appended 2 trial(s) to left_agg datasets
# []
# []
# [116]
# [523]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 431 1557 1679]
# appended 3 trial(s) to right_agg datasets
# []
# []
# [376]
# [1896]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [361]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [1450]
# appended 1 trial(s) to right_agg datasets
# [767]
# []
# appended 1 trial(s) to left_agg datasets
# [ 529  713  771 1105]
# []
# appended 4 trial(s) to left_agg datasets
# [1707]
# [299]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [1242]
# appended 1 trial(s) to right_agg datasets
# []
# [ 285 1324]
# appended 2 trial(s) to right_agg datasets
# [  55 1736]
# [324 539 942]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [1257]
# [1307]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# []
# [502]
# []
# appended 1 trial(s) to left_agg datasets
# [1641]
# []
# appended 1 trial(s) to left_agg datasets
# [1151]
# [1930]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1062]
# [1243 1823]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [129 428]
# [373]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1218 1490 1764 1894]
# []
# appended 4 trial(s) to left_agg datasets
# [ 36 318 528]
# [1244]
# appended 3 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [  37 1087]
# appended 2 trial(s) to right_agg datasets
# []
# [ 144  764  877 1195 1833]
# appended 5 trial(s) to right_agg datasets
# [ 974 1078 1458 1482 2019]
# [264]
# appended 5 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [388]
# appended 1 trial(s) to right_agg datasets
# [ 227 1618]
# [1626]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 678  921 2030]
# [  32 1092 2022]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 614 1729]
# []
# appended 2 trial(s) to left_agg datasets
# [ 825 1069]
# []
# appended 2 trial(s) to left_agg datasets
# [ 99 401 405]
# [ 459 1521]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [1605]
# [1310]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# []
# [ 248 1748]
# appended 2 trial(s) to right_agg datasets
# [ 755 1840]
# []
# appended 2 trial(s) to left_agg datasets
# [ 531  943 1437]
# [1215 1402 1611]
# appended 3 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# []
# [793]
# [557]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 798 1860]
# []
# appended 2 trial(s) to left_agg datasets
# []
# [995]
# appended 1 trial(s) to right_agg datasets
# [85]
# [665]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 286  863 1335]
# []
# appended 3 trial(s) to left_agg datasets
# [1357]
# []
# appended 1 trial(s) to left_agg datasets
# []
# [ 589 1750]
# appended 2 trial(s) to right_agg datasets
# [125]
# [546]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1554]
# [1509]
# appended 1 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1011]
# [  19 1187 1976]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 521 1800]
# [1291]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [619]
# []
# appended 1 trial(s) to left_agg datasets
# [886]
# [ 437 1364 1950]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [484 606]
# [ 338 1501]
# appended 2 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 126 1199]
# [65]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [ 270  326 1033]
# [ 66 926]
# appended 3 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# [ 687 1063]
# [109]
# appended 2 trial(s) to left_agg datasets
# appended 1 trial(s) to right_agg datasets
# [1207]
# [1085 1221 1404]
# appended 1 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# []
# [1765]
# appended 1 trial(s) to right_agg datasets
# []
# []
# [112 192]
# [ 754 1128 1721]
# appended 2 trial(s) to left_agg datasets
# appended 3 trial(s) to right_agg datasets
# [ 392  625  626 1251]
# []
# appended 4 trial(s) to left_agg datasets
# [1523 1815 1830]
# []
# appended 3 trial(s) to left_agg datasets
# [799]
# [1342 1737]
# appended 1 trial(s) to left_agg datasets
# appended 2 trial(s) to right_agg datasets
# Dataset 23 processed in 0.63 seconds
# Total load time = 61.58 seconds

# %%
for class_left in classes_left:
    for class_right in classes_right:
        left_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = (left_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = (right_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        att_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = (attention_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])

        left_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = (left_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = (right_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        att_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = (attention_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])  

##this will plot unprocessed data and then processed data to see the difference
left, right = 7, 12
#-------------wsmi calculation----------------
n_times = 250
dt = 0.002
sfreq = 1 / dt

ch_names = ['left_input', 'right_input', 'attention_layer']
ch_types = ['eeg', 'eeg', 'eeg']
info = mne.create_info(ch_names=ch_names, sfreq=sfreq, ch_types=ch_types)

for class_left in classes_left:
    wsmi_start = time.time()
    for class_right in classes_right: 
        if n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attleft'] == 0:
            continue            

        #reshaping data for attention left
        raw_data_left = np.concatenate([
            left_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'], 
            right_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'],
            att_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] 
            ], axis=0)

        print("raw_data_left shape =", raw_data_left.shape)  
        #Reshape into (n_channels, n_samples)
        raw_data_left = raw_data_left.reshape(3, -1)  
        print('raw data left reshaped =', raw_data_left.shape) 
        raw_left = mne.io.RawArray(raw_data_left, info)
        print("raw_data_left =", raw_left)



        #defininf event objects, arrays like [0,0,1], [500, 0, 1], [1000, 0, 1] etc
        events_left = np.array([[i * n_times, 0, 1] for i in range(0, n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attleft']) ])
        print(events_left)

        epochs_left = mne.Epochs(raw_left, events_left, event_id={'Trial': 1}, tmin=0, tmax =  0.25,  baseline=None, preload=True)

        if class_left == left and class_right == right:
            epochs_left.plot(n_epochs = 4, n_channels=3, scalings = 'auto', title="Attention Left")
            plt.show()



for class_left in classes_left:
    wsmi_start = time.time()
    for class_right in classes_right:       
        if n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attright'] == 0:  
            continue      

        #reshaping date for attention right 
        raw_data_right = np.concatenate([
            left_attright[f'left_class_{class_left}'][f'right_class_{class_right}'],
            right_attright[f'left_class_{class_left}'][f'right_class_{class_right}'],
            att_attright[f'left_class_{class_left}'][f'right_class_{class_right}']            
        ], axis=0)

        #print('raw_data_right shape =', raw_data_right.shape)
        raw_data_right = raw_data_right.reshape(3, -1)
        #print('raw_data_right reshaped =', raw_data_right.shape)
        raw_right = mne.io.RawArray(raw_data_right, info)
        #print('raw_data_right =', raw_right)


        events_right = np.array([[i * n_times, 0, 1] for i in range(0, n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attright']) ]) 
        print(events_right)

        epochs_right = mne.Epochs(raw_right, events_right, event_id={'Trial': 1}, tmin=0, tmax = 0.25, baseline=None, preload=True)
        
        if class_left == left and class_right == right:
            epochs_right.plot(n_epochs = 4, n_channels=3, scalings = 'auto', title="Attention Right")
            plt.show()
        


def preprocess_data(data):
    # data = detrend(data, axis = 0)   #data seems to look nicer if i do this

    for i in range(len(data)):
        data[i] = detrend(data[i])

    data = zscore(data, axis = 0)
    return data

for class_left in classes_left:
    for class_right in classes_right:
        left_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = preprocess_data(left_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = preprocess_data(right_input_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        att_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] = preprocess_data(attention_LFP_attleft_all[f'left_class_{class_left}'][f'right_class_{class_right}'])

        left_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = preprocess_data(left_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        right_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = preprocess_data(right_input_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])
        att_attright[f'left_class_{class_left}'][f'right_class_{class_right}'] = preprocess_data(attention_LFP_attright_all[f'left_class_{class_left}'][f'right_class_{class_right}'])  


#------------plotting again post processing-----------------------
wsmi_means = {}
wsmi_stdevs = {}


for class_left in classes_left:
    wsmi_start = time.time()
    for class_right in classes_right: 
        if n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attleft'] == 0:
            continue            

        #reshaping data for attention left
        raw_data_left = np.concatenate([
            left_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'], 
            right_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'],
            att_attleft[f'left_class_{class_left}'][f'right_class_{class_right}'] 
            ], axis=0)

        print("raw_data_left shape =", raw_data_left.shape)  
        #Reshape into (n_channels, n_samples)
        raw_data_left = raw_data_left.reshape(3, -1)  
        print('raw data left reshaped =', raw_data_left.shape) 
        raw_left = mne.io.RawArray(raw_data_left, info)
        print("raw_data_left =", raw_left)



        #defininf event objects, arrays like [0,0,1], [500, 0, 1], [1000, 0, 1] etc
        events_left = np.array([[i * n_times, 0, 1] for i in range(0, n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attleft']) ])
        print(events_left)

        epochs_left = mne.Epochs(raw_left, events_left, event_id={'Trial': 1}, tmin=0, tmax =  0.25,  baseline=None, preload=True)

        if class_left == left and class_right == right:
            epochs_left.plot(n_epochs = 4, n_channels=3, scalings = 'auto', title="Attention Left")
            plt.show()



for class_left in classes_left:
    wsmi_start = time.time()
    for class_right in classes_right:       
        if n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attright'] == 0:  
            continue      

        #reshaping date for attention right 
        raw_data_right = np.concatenate([
            left_attright[f'left_class_{class_left}'][f'right_class_{class_right}'],
            right_attright[f'left_class_{class_left}'][f'right_class_{class_right}'],
            att_attright[f'left_class_{class_left}'][f'right_class_{class_right}']            
        ], axis=0)

        #print('raw_data_right shape =', raw_data_right.shape)
        raw_data_right = raw_data_right.reshape(3, -1)
        #print('raw_data_right reshaped =', raw_data_right.shape)
        raw_right = mne.io.RawArray(raw_data_right, info)
        #print('raw_data_right =', raw_right)


        events_right = np.array([[i * n_times, 0, 1] for i in range(0, n_values_sum[f'left_class_{class_left}'][f'right_class_{class_right}']['attright']) ]) 
        print(events_right)

        epochs_right = mne.Epochs(raw_right, events_right, event_id={'Trial': 1}, tmin=0, tmax = 0.25, baseline=None, preload=True)
        
        if class_left == left and class_right == right:
            epochs_right.plot(n_epochs = 4, n_channels=3, scalings = 'auto', title="Attention Right")
            plt.show()
# Out:
# raw_data_left shape = (9, 250)
# raw data left reshaped = (3, 750)
# raw_data_left = <RawArray | 3 x 750 (1.5 s), ~25 kB, data loaded>
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (9, 250)
# raw data left reshaped = (3, 750)
# raw_data_left = <RawArray | 3 x 750 (1.5 s), ~25 kB, data loaded>
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (9, 250)
# raw data left reshaped = (3, 750)
# raw_data_left = <RawArray | 3 x 750 (1.5 s), ~25 kB, data loaded>
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (45, 250)
# raw data left reshaped = (3, 3750)
# raw_data_left = <RawArray | 3 x 3750 (7.5 s), ~95 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (45, 250)
# raw data left reshaped = (3, 3750)
# raw_data_left = <RawArray | 3 x 3750 (7.5 s), ~95 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (42, 250)
# raw data left reshaped = (3, 3500)
# raw_data_left = <RawArray | 3 x 3500 (7.0 s), ~89 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (42, 250)
# raw data left reshaped = (3, 3500)
# raw_data_left = <RawArray | 3 x 3500 (7.0 s), ~89 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (42, 250)
# raw data left reshaped = (3, 3500)
# raw_data_left = <RawArray | 3 x 3500 (7.0 s), ~89 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# raw_data_left shape = (42, 250)
# raw data left reshaped = (3, 3500)
# raw_data_left = <RawArray | 3 x 3500 (7.0 s), ~89 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (45, 250)
# raw data left reshaped = (3, 3750)
# raw_data_left = <RawArray | 3 x 3750 (7.5 s), ~95 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (9, 250)
# raw data left reshaped = (3, 750)
# raw_data_left = <RawArray | 3 x 750 (1.5 s), ~25 kB, data loaded>
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (12, 250)
# raw data left reshaped = (3, 1000)
# raw_data_left = <RawArray | 3 x 1000 (2.0 s), ~31 kB, data loaded>
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]
#  [750   0   1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (36, 250)
# raw data left reshaped = (3, 3000)
# raw_data_left = <RawArray | 3 x 3000 (6.0 s), ~78 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# raw_data_left shape = (48, 250)
# raw data left reshaped = (3, 4000)
# raw_data_left = <RawArray | 3 x 4000 (8.0 s), ~101 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (51, 250)
# raw data left reshaped = (3, 4250)
# raw_data_left = <RawArray | 3 x 4250 (8.5 s), ~107 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]
#  [4000    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (48, 250)
# raw data left reshaped = (3, 4000)
# raw_data_left = <RawArray | 3 x 4000 (8.0 s), ~101 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (12, 250)
# raw data left reshaped = (3, 1000)
# raw_data_left = <RawArray | 3 x 1000 (2.0 s), ~31 kB, data loaded>
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]
#  [750   0   1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (42, 250)
# raw data left reshaped = (3, 3500)
# raw_data_left = <RawArray | 3 x 3500 (7.0 s), ~89 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (45, 250)
# raw data left reshaped = (3, 3750)
# raw_data_left = <RawArray | 3 x 3750 (7.5 s), ~95 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (27, 250)
# raw data left reshaped = (3, 2250)
# raw_data_left = <RawArray | 3 x 2250 (4.5 s), ~60 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (45, 250)
# raw data left reshaped = (3, 3750)
# raw_data_left = <RawArray | 3 x 3750 (7.5 s), ~95 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# raw_data_left shape = (12, 250)
# raw data left reshaped = (3, 1000)
# raw_data_left = <RawArray | 3 x 1000 (2.0 s), ~31 kB, data loaded>
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]
#  [750   0   1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (21, 250)
# raw data left reshaped = (3, 1750)
# raw_data_left = <RawArray | 3 x 1750 (3.5 s), ~48 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (48, 250)
# raw data left reshaped = (3, 4000)
# raw_data_left = <RawArray | 3 x 4000 (8.0 s), ~101 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]]
# raw_data_left shape = (15, 250)
# raw data left reshaped = (3, 1250)
# raw_data_left = <RawArray | 3 x 1250 (2.5 s), ~37 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# raw_data_left = <RawArray | 3 x 1500 (3.0 s), ~42 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# raw_data_left shape = (24, 250)
# raw data left reshaped = (3, 2000)
# raw_data_left = <RawArray | 3 x 2000 (4.0 s), ~54 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# <MNEBrowseFigure size 840x602 with 4 Axes>
# raw_data_left shape = (30, 250)
# raw data left reshaped = (3, 2500)
# raw_data_left = <RawArray | 3 x 2500 (5.0 s), ~66 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# raw_data_left shape = (39, 250)
# raw data left reshaped = (3, 3250)
# raw_data_left = <RawArray | 3 x 3250 (6.5 s), ~83 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# raw_data_left shape = (42, 250)
# raw data left reshaped = (3, 3500)
# raw_data_left = <RawArray | 3 x 3500 (7.0 s), ~89 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# raw_data_left shape = (51, 250)
# raw data left reshaped = (3, 4250)
# raw_data_left = <RawArray | 3 x 4250 (8.5 s), ~107 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]
#  [4000    0    1]]
# raw_data_left shape = (33, 250)
# raw data left reshaped = (3, 2750)
# raw_data_left = <RawArray | 3 x 2750 (5.5 s), ~72 kB, data loaded>
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# raw_data_left shape = (18, 250)
# raw data left reshaped = (3, 1500)
# ...
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]
#  [4000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]
#  [4000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]
#  [4000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]
#  [4000    0    1]
#  [4250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]
#  [750   0   1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]
#  [4000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]]
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[  0   0   1]
#  [250   0   1]
#  [500   0   1]
#  [750   0   1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]]
# [[   0    0    1]
#  [ 250    0    1]
#  [ 500    0    1]
#  [ 750    0    1]
#  [1000    0    1]
#  [1250    0    1]
#  [1500    0    1]
#  [1750    0    1]
#  [2000    0    1]
#  [2250    0    1]
#  [2500    0    1]
#  [2750    0    1]
#  [3000    0    1]
#  [3250    0    1]
#  [3500    0    1]
#  [3750    0    1]]
